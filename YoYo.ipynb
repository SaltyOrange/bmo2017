# %%
# %matplotlib inline

# %%
from pymote import NetworkGenerator
net_gen = NetworkGenerator(20)
net = net_gen.generate_random_network()
net.show()

# %%
from SetupYoYo import SetupYoYo
from YoYo import YoYo
net.algorithms = ((SetupYoYo, {}), (YoYo, {}))
write_pickle(net, "YoYo.npc.gz")

# %%
sim = Simulation(net)
sim.run()
